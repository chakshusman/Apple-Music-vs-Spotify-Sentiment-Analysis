# %%
import os
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tweet_count = 1000
text_query = "apple music"
since_date = "2016-01-01"
until_date = "2020-01-01"

os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
tweets = pd.read_json('text-query-tweets.json', lines=True)

# %%
tweets.head(10)
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
# 5  snscrape.modules.twitter.Tweet
# 6  snscrape.modules.twitter.Tweet
# 7  snscrape.modules.twitter.Tweet
# 8  snscrape.modules.twitter.Tweet
# 9  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/shibayanhatena/status/1212...
# 1  https://twitter.com/weareDRES_/status/12121613...
# 2  https://twitter.com/DrekoElProdigio/status/121...
# 3  https://twitter.com/kakicchysmusic4/status/121...
# 4  https://twitter.com/January12_/status/12121610...
# 5  https://twitter.com/ryjjeaux/status/1212160631...
# 6  https://twitter.com/AlexShelnutt/status/121216...
# 7  https://twitter.com/DJLuckyC/status/1212160406...
# 8  https://twitter.com/SuperB_456/status/12121603...
# 9  https://twitter.com/peregrine/status/121216034...
#
#                        date  \
# 0 2019-12-31 23:59:30+00:00
# 1 2019-12-31 23:59:14+00:00
# 2 2019-12-31 23:59:05+00:00
# 3 2019-12-31 23:58:30+00:00
# 4 2019-12-31 23:57:59+00:00
# 5 2019-12-31 23:56:30+00:00
# 6 2019-12-31 23:55:58+00:00
# 7 2019-12-31 23:55:36+00:00
# 8 2019-12-31 23:55:22+00:00
# 9 2019-12-31 23:55:20+00:00
#
#                                              content  \
# 0  2020年の夜が明けた！\n陽は毎年必ず東から上がるのです！🤙🏽😎\n#JacksonBro...
# 1  We're Playing @1810ojeman on Thursday Jan 9 Do...
# 2  Antes de que se acabe el año. \nEscucha Mi tem...
# 3  I BOUGHT A NEW KEYBOARD &amp; TRY　\n https://t...
# 4  Just not understand why it’s not on Apple Musi...
# 5  Apple Music need the explicit version of Set I...
# 6  @ray_thomas6 @jeremymckinnon Apple Music is lying
# 7  #BOTHSIDEZ \n@gwb_doe \nFt @KiddoMarv  \nOUT N...
# 8  @OH_mes2 @B_hundred_Hyun #BAEKHYUN's #UNVillag...
# 9  2020: I'm building code and tools for me and n...
#
#                                      renderedContent                   id  \
# 0  2020年の夜が明けた！\n陽は毎年必ず東から上がるのです！🤙🏽😎\n#JacksonBro...  1212161387029336064
# 1  We're Playing @1810ojeman on Thursday Jan 9 Do...  1212161322550464513
# 2  Antes de que se acabe el año. \nEscucha Mi tem...  1212161281651806210
# 3  I BOUGHT A NEW KEYBOARD &amp; TRY　\n tmw.bz/0C...  1212161135274708992
# 4  Just not understand why it’s not on Apple Musi...  1212161004622241792
# 5  Apple Music need the explicit version of Set I...  1212160631970975751
# 6  @ray_thomas6 @jeremymckinnon Apple Music is lying  1212160499984601088
# 7  #BOTHSIDEZ \n@gwb_doe \nFt @KiddoMarv  \nOUT N...  1212160406090850304
# 8  @OH_mes2 @B_hundred_Hyun #BAEKHYUN's #UNVillag...  1212160349761409026
# 9  2020: I'm building code and tools for me and n...  1212160340827541505
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 6  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 7  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 8  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 9  {'_type': 'snscrape.modules.twitter.User', 'us...           1
#
#    retweetCount  likeCount  ...  \
# 0             2          5  ...
# 1             0          1  ...
# 2             0          0  ...
# 3             0          0  ...
# 4             0          0  ...
# 5             0          3  ...
# 6             0          1  ...
# 7             0          0  ...
# 8             0          0  ...
# 9             0          7  ...
#
#                                                media  retweetedTweet  \
# 0                                               None             NaN
# 1  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 2                                               None             NaN
# 3                                               None             NaN
# 4                                               None             NaN
# 5                                               None             NaN
# 6                                               None             NaN
# 7                                               None             NaN
# 8                                               None             NaN
# 9                                               None             NaN
#
#                                          quotedTweet inReplyToTweetId  \
# 0                                               None              NaN
# 1                                               None              NaN
# 2                                               None              NaN
# 3                                               None              NaN
# 4  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 5                                               None              NaN
# 6                                               None     1.212156e+18
# 7                                               None              NaN
# 8                                               None     1.212159e+18
# 9                                               None              NaN
#
#                                        inReplyToUser  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'_type': 'snscrape.modules.twitter.User', 'us...
# 7                                               None
# 8  {'_type': 'snscrape.modules.twitter.User', 'us...
# 9                                               None
#
#                                       mentionedUsers  \
# 0                                               None
# 1                                               None
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3                                               None
# 4                                               None
# 5                                               None
# 6  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 7  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 8  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 9                                               None
#
#                                          coordinates  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'_type': 'snscrape.modules.twitter.Coordinate...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                                place  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'_type': 'snscrape.modules.twitter.Place', 'f...
# 7                                               None
# 8                                               None
# 9                                               None
#
#                                             hashtags  cashtags
# 0  [JacksonBrowne, NowPlaying, NowListening, Appl...       NaN
# 1  [indie, music, new, alternative, Houston, live...       NaN
# 2  [newmusic2019, newmusicsoon, share, comment, r...       NaN
# 3                        [applemusic, iTunes, music]       NaN
# 4                                               None       NaN
# 5                                               None       NaN
# 6                                               None       NaN
# 7                                        [BOTHSIDEZ]       NaN
# 8                              [BAEKHYUN, UNVillage]       NaN
# 9                                               None       NaN
#
# [10 rows x 28 columns]

# %%
tweets.to_csv('applemusic.csv', sep=',', index=False)

# %%
data = pd.read_csv('applemusic.csv')

# %%
data.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/shibayanhatena/status/1212...
# 1  https://twitter.com/weareDRES_/status/12121613...
# 2  https://twitter.com/DrekoElProdigio/status/121...
# 3  https://twitter.com/kakicchysmusic4/status/121...
# 4  https://twitter.com/January12_/status/12121610...
#
#                         date  \
# 0  2019-12-31 23:59:30+00:00
# 1  2019-12-31 23:59:14+00:00
# 2  2019-12-31 23:59:05+00:00
# 3  2019-12-31 23:58:30+00:00
# 4  2019-12-31 23:57:59+00:00
#
#                                              content  \
# 0  2020年の夜が明けた！\n陽は毎年必ず東から上がるのです！🤙🏽😎\n#JacksonBro...
# 1  We're Playing @1810ojeman on Thursday Jan 9 Do...
# 2  Antes de que se acabe el año. \nEscucha Mi tem...
# 3  I BOUGHT A NEW KEYBOARD &amp; TRY　\n https://t...
# 4  Just not understand why it’s not on Apple Musi...
#
#                                      renderedContent                   id  \
# 0  2020年の夜が明けた！\n陽は毎年必ず東から上がるのです！🤙🏽😎\n#JacksonBro...  1212161387029336064
# 1  We're Playing @1810ojeman on Thursday Jan 9 Do...  1212161322550464513
# 2  Antes de que se acabe el año. \nEscucha Mi tem...  1212161281651806210
# 3  I BOUGHT A NEW KEYBOARD &amp; TRY　\n tmw.bz/0C...  1212161135274708992
# 4  Just not understand why it’s not on Apple Musi...  1212161004622241792
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  \
# 0             2          5  ...
# 1             0          1  ...
# 2             0          0  ...
# 3             0          0  ...
# 4             0          0  ...
#
#                                                media  retweetedTweet  \
# 0                                                NaN             NaN
# 1  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                          quotedTweet inReplyToTweetId  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#
#   inReplyToUser                                     mentionedUsers  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3           NaN                                                NaN
# 4           NaN                                                NaN
#
#   coordinates place                                           hashtags  \
# 0         NaN   NaN  ['JacksonBrowne', 'NowPlaying', 'NowListening'...
# 1         NaN   NaN  ['indie', 'music', 'new', 'alternative', 'Hous...
# 2         NaN   NaN  ['newmusic2019', 'newmusicsoon', 'share', 'com...
# 3         NaN   NaN                  ['applemusic', 'iTunes', 'music']
# 4         NaN   NaN                                                NaN
#
#    cashtags
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 28 columns]

# %%
data = data[['content','date']]

# %%
data.head()
# Out:
#                                              content  \
# 0  2020年の夜が明けた！\n陽は毎年必ず東から上がるのです！🤙🏽😎\n#JacksonBro...
# 1  We're Playing @1810ojeman on Thursday Jan 9 Do...
# 2  Antes de que se acabe el año. \nEscucha Mi tem...
# 3  I BOUGHT A NEW KEYBOARD &amp; TRY　\n https://t...
# 4  Just not understand why it’s not on Apple Musi...
#
#                         date
# 0  2019-12-31 23:59:30+00:00
# 1  2019-12-31 23:59:14+00:00
# 2  2019-12-31 23:59:05+00:00
# 3  2019-12-31 23:58:30+00:00
# 4  2019-12-31 23:57:59+00:00

# %%
data['content'].isnull().any()
# Out:
# False

# %%
data['date'].isnull().any()
# Out:
# False

# %%
data.shape
# Out:
# (1000, 2)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
data['compound'] = [analyser.polarity_scores(x)['compound'] for x in data['content']]
data['neg'] = [analyser.polarity_scores(x)['neg'] for x in data['content']]
data['neu'] = [analyser.polarity_scores(x)['neu'] for x in data['content']]
data['pos'] = [analyser.polarity_scores(x)['pos'] for x in data['content']]

# %%
data
# Out:
#                                                content  \
# 0    2020年の夜が明けた！\n陽は毎年必ず東から上がるのです！🤙🏽😎\n#JacksonBro...
# 1    We're Playing @1810ojeman on Thursday Jan 9 Do...
# 2    Antes de que se acabe el año. \nEscucha Mi tem...
# 3    I BOUGHT A NEW KEYBOARD &amp; TRY　\n https://t...
# 4    Just not understand why it’s not on Apple Musi...
# ..                                                 ...
# 995  Now Streaming on @applemusic spotify https://t...
# 996  #NEW #JMAX #CantLose @AppleMusic @tidalhifi sp...
# 997  THERES A TRAP VERSION OF BELLAS LULLABY ON APP...
# 998  From "Teardrops on a blank page" album, #NowPl...
# 999                @AppleMusic https://t.co/Ut6KKzpWkY
#
#                           date  compound    neg    neu    pos
# 0    2019-12-31 23:59:30+00:00    0.7351  0.000  0.807  0.193
# 1    2019-12-31 23:59:14+00:00   -0.4588  0.099  0.864  0.037
# 2    2019-12-31 23:59:05+00:00    0.2960  0.000  0.932  0.068
# 3    2019-12-31 23:58:30+00:00    0.0000  0.000  1.000  0.000
# 4    2019-12-31 23:57:59+00:00   -0.7840  0.392  0.459  0.148
# ..                         ...       ...    ...    ...    ...
# 995  2019-12-31 19:04:08+00:00    0.0000  0.000  1.000  0.000
# 996  2019-12-31 19:03:47+00:00    0.0000  0.000  1.000  0.000
# 997  2019-12-31 19:03:18+00:00   -0.5994  0.329  0.671  0.000
# 998  2019-12-31 19:03:16+00:00    0.0000  0.000  1.000  0.000
# 999  2019-12-31 19:02:56+00:00    0.0000  0.000  1.000  0.000
#
# [1000 rows x 6 columns]

# %%
am_neg=data[data['neg'] !=0]
am_neg
# Out:
#                                                content  \
# 1    We're Playing @1810ojeman on Thursday Jan 9 Do...
# 4    Just not understand why it’s not on Apple Musi...
# 6    @ray_thomas6 @jeremymckinnon Apple Music is lying
# 14   @D0ntGetChipped Hopefully they drop it on Appl...
# 16   So mad when they took this off of Apple Music ...
# ..                                                 ...
# 978  snapchat bout to hate me .. Rocky done add thi...
# 979  I'll keep this short but ten years ago I was w...
# 983  fuck a friend needs to be on apple music !!! h...
# 994  I have this hard time with Whitney Houston son...
# 997  THERES A TRAP VERSION OF BELLAS LULLABY ON APP...
#
#                           date  compound    neg    neu    pos
# 1    2019-12-31 23:59:14+00:00   -0.4588  0.099  0.864  0.037
# 4    2019-12-31 23:57:59+00:00   -0.7840  0.392  0.459  0.148
# 6    2019-12-31 23:55:58+00:00   -0.5267  0.405  0.595  0.000
# 14   2019-12-31 23:52:38+00:00    0.1531  0.164  0.625  0.211
# 16   2019-12-31 23:52:31+00:00   -0.5413  0.259  0.741  0.000
# ..                         ...       ...    ...    ...    ...
# 978  2019-12-31 19:08:11+00:00   -0.1779  0.134  0.758  0.108
# 979  2019-12-31 19:08:09+00:00   -0.8382  0.142  0.858  0.000
# 983  2019-12-31 19:07:27+00:00   -0.2905  0.264  0.543  0.193
# 994  2019-12-31 19:04:10+00:00    0.7964  0.085  0.725  0.190
# 997  2019-12-31 19:03:18+00:00   -0.5994  0.329  0.671  0.000
#
# [324 rows x 6 columns]

# %%
am_neg.shape
# Out:
# (324, 6)

# %%
neg_sen = am_neg['neg']
date_sen = am_neg['date']

# %%
fig, ax = plt.subplots(figsize =(15, 10))
ax.tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)
ax.plot_date(date_sen,neg_sen,alpha=0.5,linestyle='solid',color='red')
plt.xlabel("Date(2016-2020)")
plt.ylabel("Negative Sentiment")
plt.title("Apple Music")
# Out:
# Text(0.5, 1.0, 'Apple Music')

# %%
am_pos = data[data['pos'] !=0]
am_pos
# Out:
#                                                content  \
# 0    2020年の夜が明けた！\n陽は毎年必ず東から上がるのです！🤙🏽😎\n#JacksonBro...
# 1    We're Playing @1810ojeman on Thursday Jan 9 Do...
# 2    Antes de que se acabe el año. \nEscucha Mi tem...
# 4    Just not understand why it’s not on Apple Musi...
# 8    @OH_mes2 @B_hundred_Hyun #BAEKHYUN's #UNVillag...
# ..                                                 ...
# 981  Vitamin &amp; Chloe - TECHNOPRIMAL\nhttps://t....
# 982  Nearly 2 decades of #AUGUSTANA music on this n...
# 983  fuck a friend needs to be on apple music !!! h...
# 993  where art thou? by N3JI is on itunes/apple mus...
# 994  I have this hard time with Whitney Houston son...
#
#                           date  compound    neg    neu    pos
# 0    2019-12-31 23:59:30+00:00    0.7351  0.000  0.807  0.193
# 1    2019-12-31 23:59:14+00:00   -0.4588  0.099  0.864  0.037
# 2    2019-12-31 23:59:05+00:00    0.2960  0.000  0.932  0.068
# 4    2019-12-31 23:57:59+00:00   -0.7840  0.392  0.459  0.148
# 8    2019-12-31 23:55:22+00:00    0.8442  0.000  0.755  0.245
# ..                         ...       ...    ...    ...    ...
# 981  2019-12-31 19:07:47+00:00    0.2960  0.000  0.804  0.196
# 982  2019-12-31 19:07:30+00:00    0.8555  0.000  0.761  0.239
# 983  2019-12-31 19:07:27+00:00   -0.2905  0.264  0.543  0.193
# 993  2019-12-31 19:04:17+00:00    0.5719  0.000  0.748  0.252
# 994  2019-12-31 19:04:10+00:00    0.7964  0.085  0.725  0.190
#
# [434 rows x 6 columns]

# %%
pos_sen = am_pos['pos']
date_sen_pos = am_pos['date']

# %%
fig, ax = plt.subplots(figsize =(15, 10))
ax.tick_params(axis='x',which='both', bottom=False, top=False, labelbottom=False)
ax.plot_date(date_sen_pos,pos_sen,alpha=0.5,linestyle='solid',color='green')
plt.xlabel("Date(2016-2020)")
plt.ylabel("Positive Sentiment")
plt.title("Apple Music")
# Out:
# Text(0.5, 1.0, 'Apple Music')
